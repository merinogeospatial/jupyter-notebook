# %%
import tweepy
from textblob import TextBlob
import csv

TWEET_txt = []
polarity = []
subjectivity = []

csv_out = open('spacex.csv', 'w')

consumer_key = 'pWfx4N4Cgo8aXJ89bZ48MdTVC'
consumer_secret = '5NtO4texOKXzGIGnOGTWfzqsBX0tK47Lxt8kipivxZHDChhtPP'

access_token = '2315182878-QWMsMerPllvQ665UfGDeIxNPhkb61Wx0TeY01EA'
access_token_secret = 'OJLKImNniqI5CRbKLe6XAHlYJ8OlCw6VQF4qcILuGBAP7'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

public_tweets = api.search(q='spacex', count=100)

headers = "TWEET" + "," + "POLARITY" + "," + "SUBJECTIVITY" + "\n"
csv_out.write(headers)
scrub = str.maketrans(dict.fromkeys('Sentiment(polarity=subjectivity=)'))
                      
for tweet in public_tweets:
    TXT = (tweet.text)
    print (TXT)
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
    print("")
    out = str(TXT).replace(","," ") + "," + str(analysis.sentiment).translate(scrub) + "\n"
    csv_out.write(out)
    
    
    
csv_out.close()
# Out:
# @AmazingSpace2 @NASA @SpaceX Totally know you mean that in a fun way, but for passing eyeballs an interesting thing… https://t.co/Qbmwai2MYG
# Sentiment(polarity=0.121875, subjectivity=0.534375)
#
# RT @ClickHole: Space Flight Setback: SpaceX Has Lost A Falcon 9 Rocket After It Landed In A Mean Old Neighbor’s Backyard https://t.co/Gs1Gg…
# Sentiment(polarity=-0.10625, subjectivity=0.44375)
#
# RT @christianbok: Marie Claire takes an interest in the career of Gwynne Shotwell—(via @webdevmason): https://t.co/VIlvRkInpO
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @SpaceX_x @BrianNoahYT Jaman 😂 kapppppppaaaa
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @ClickHole: Space Flight Setback: SpaceX Has Lost A Falcon 9 Rocket After It Landed In A Mean Old Neighbor’s Backyard https://t.co/Gs1Gg…
# Sentiment(polarity=-0.10625, subjectivity=0.44375)
#
# RT @manuginobili: Very exciting visit to @SpaceX with a few teammates. We loved it! Thanks for having us! https://t.co/S1VxumBqwy
# Sentiment(polarity=0.32875, subjectivity=0.525)
#
# RT @ClickHole: Space Flight Setback: SpaceX Has Lost A Falcon 9 Rocket After It Landed In A Mean Old Neighbor’s Backyard https://t.co/Gs1Gg…
# Sentiment(polarity=-0.10625, subjectivity=0.44375)
#
# RT @webdevMason: Gwynne Shotwell is a personal hero. She’s President &amp; COO at SpaceX.
#
# “SpaceX has a female president?”
#
# Yeah, it does. If…
# Sentiment(polarity=0.0, subjectivity=0.23333333333333334)
#
# @AstronautAbby Abby!  You don't need a *Rocket*🚀to go to #MARS with those leggings! Hey Astrobuddy @spacechelle at… https://t.co/cJAIURWBLy
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# SpaceX Denies Any Oversights in Classified Satellite Launch https://t.co/R0gUgPfNMI
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @SpaceX: Dragon is headed to port with ~4,100 pounds of scientific research and hardware for a cargo handover to @NASA. https://t.co/7eb…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# #vid • @YouTube 《 https://t.co/VPCDLQx97k 》 SpaceX’s Mysterious Zuma Mission, What on Earth Happened? : #HyperLink… https://t.co/KmRMquOfmN
# Sentiment(polarity=0.0, subjectivity=1.0)
#
# RT @NorwichAS: SpaceX realign Falcon Heavy Static Fire test for Tuesday - The second most important part of Falcon Heavy’s debut has arrive…
# Sentiment(polarity=0.1666666666666667, subjectivity=0.5666666666666667)
#
# @AJ_FI @pbdes Recovered fairing - quicker than spacex - needs some TLC
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @ElonMuskNewsOrg: "We have essentially no patents in SpaceX… if we published patents… the Chinese would just use them as a recipe book."…
# Sentiment(polarity=0.0, subjectivity=0.15)
#
# #SpaceX The Space Review: The mystery of #Zuma https://t.co/mZ2XmQ2sb1
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @ClickHole: Space Flight Setback: SpaceX Has Lost A Falcon 9 Rocket After It Landed In A Mean Old Neighbor’s Backyard https://t.co/Gs1Gg…
# Sentiment(polarity=-0.10625, subjectivity=0.44375)
#
# @AriParranda @clarin @todonoticias Yo te recomiendo que dejes de seguir a cuenta de noticias y en su lugar sigas a… https://t.co/VsPuVMcEyj
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @FortuneMagazine: SpaceX will test the engines of the world’s most powerful rocket today https://t.co/aDxdWWw3XB
# Sentiment(polarity=0.4, subjectivity=0.75)
#
# Station cargo ship brings science down to Earth - @CBSNews : https://t.co/xl3ubBlUY4
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
#
# RT @ElonMuskNewsOrg: "We have essentially no patents in SpaceX… if we published patents… the Chinese would just use them as a recipe book."…
# Sentiment(polarity=0.0, subjectivity=0.15)
#
# @NASA @isro @JAXA_en @esa
# @csa_asc
# @SpaceX @spacegovuk @roscosmos
# @neiltyson
# @BillNye @TheRealBuzz
#
# This is a craz… https://t.co/5cFZwg6rvU
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @TIME: SpaceX is about to test the world's most powerful rocket https://t.co/mgznhJutS1
# Sentiment(polarity=0.4, subjectivity=0.75)
#
# RT @SpaceX: After a month-long stay at the @Space_Station, Dragon returns home tomorrow with ~4,100 pounds of @NASA cargo and research mate…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @SpaceX: The three departure burns to move Dragon away from the @Space_Station are complete. https://t.co/3cyYatpqRb
# Sentiment(polarity=0.1, subjectivity=0.4)
#
# SpaceX fuels Falcon Heavy at KSC ahead of next test fire attempt
# Sentiment(polarity=-0.1, subjectivity=0.25)
#
# Strange Sky Spiral May Come from Secretive SpaceX Zuma Launch
# Sentiment(polarity=-0.05, subjectivity=0.15)
#
# @NASASpaceflight @nasa Vs @spacex - Bring It On!
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# Thanks to SpaceX for making this photo available freely on @unsplash 🎁 https://t.co/y6j9gpw50z
# Sentiment(polarity=0.3333333333333333, subjectivity=0.46666666666666673)
#
# RT @maxmaxmaxr12: Жаль, что Стругацкие не дожили до момента, когда их книги начинают приобретать очертания действительности.
#
# https://t.c…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# I said BYE BYE.... https://t.co/WeGtKzvIol
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# Ik heb een video toegevoegd aan een @YouTube-afspeellijst: https://t.co/yc0TuMIOVQ SpaceX Makes History | MARS
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @TheLastCrypto: @elonmusk @elonmusk nice power move using sacred symbols to make yourself look powerful. Your a hoser #Musk. Impressed b…
# Sentiment(polarity=0.6333333333333333, subjectivity=1.0)
#
# @NancyCollister1 @kimbal @SpaceX @elonmusk Maybe if you didn't speak in all caps 24/7 people could actually take you seriously
# Sentiment(polarity=-0.16666666666666666, subjectivity=0.3833333333333333)
#
# RT @ChemaTierraNews: Falcon Heavy, el cohete de #SpaceX que pretende llegar a Marte, está a punto de despegar. 🚀
# https://t.co/C7tTkr6sv8 ht…
# Sentiment(polarity=-0.2, subjectivity=0.5)
#
# RT @NYTScience: SpaceX launched something last week. That's about all we know for certain. But it appears something went wrong. https://t.c…
# Sentiment(polarity=-0.09523809523809523, subjectivity=0.5126984126984127)
#
# #SpaceX Delivers “Secret” Satellite… Or Not?  https://t.co/Ov3Lu8kQMY https://t.co/GBWtof9VEE
# Sentiment(polarity=-0.4, subjectivity=0.7)
#
# SpaceX gets ready to fire up Falcon Heavy for the first time at Cape Canaveral  https://t.co/rLHScuR7Wt #EndTimes #SkyWatch
# Sentiment(polarity=0.08333333333333333, subjectivity=0.4444444444444444)
#
# RT @BlackGryph0n: Hotdog re-entry @SpaceX https://t.co/gn8JxuU6eP
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @Jeff2Serenity @TrampolinRocket @TheLurioReport @SpaceX Just got followed by a bot!
# Go figure!
# Reported &amp; blocked! 😎
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @webdevMason: Gwynne Shotwell is a personal hero. She’s President &amp; COO at SpaceX.
#
# “SpaceX has a female president?”
#
# Yeah, it does. If…
# Sentiment(polarity=0.0, subjectivity=0.23333333333333334)
#
# RT @SpaceComExpo: @SpaceX is about to test their most powerful rocket, the Falcon Heavy, tomorrow. Stay tuned! https://t.co/BhL1acj1BP http…
# Sentiment(polarity=0.18333333333333335, subjectivity=0.6666666666666666)
#
# SpaceX realign Falcon Heavy Static Fire test for Tuesday - The second most important part of Falcon Heavy’s debut h… https://t.co/3VVX6EDOVN
# Sentiment(polarity=0.1666666666666667, subjectivity=0.5666666666666667)
#
# #digitalecom SpaceX to fire up Falcon Heavy's 27 engines this week - CNET - Elon Musk's next big thing will get ful… https://t.co/daoOgEnKpo
# Sentiment(polarity=-0.06666666666666667, subjectivity=0.19999999999999998)
#
# RT @MikeQuindazzi: Top #tech companies where people most want to work. @SpaceX @Google @Shopify @Tesla @Netflix @SlackHQ @Atlassian @Hulu @…
# Sentiment(polarity=0.5, subjectivity=0.5)
#
# RT @ClickHole: Space Flight Setback: SpaceX Has Lost A Falcon 9 Rocket After It Landed In A Mean Old Neighbor’s Backyard https://t.co/Gs1Gg…
# Sentiment(polarity=-0.10625, subjectivity=0.44375)
#
# SpaceX to fire up Falcon Heavy's 27 engines this week - CNET - Elon Musk's next big thing will get fully lit up for… https://t.co/tHB2quWTBx
# Sentiment(polarity=-0.06666666666666667, subjectivity=0.19999999999999998)
#
# Intriguing #Space news from https://t.co/ptEDfWjuXm: Safety Panel Raises Concerns about SpaceX Falcon 9 Pressure Ve… https://t.co/8vVOfU1A7A
# Sentiment(polarity=0.30000000000000004, subjectivity=0.4)
#
# Did SpaceX just lose a secret US spy satellite?
# Sentiment(polarity=-0.4, subjectivity=0.7)
#
# I added a video to a @YouTube playlist https://t.co/SPTPhE9ouK SpaceX CRS-13 Falcon 9 Rocket Launch and Landing
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# DID YOU SEE THIS?
# World’s Coolest Selfie!
# #selfie #space #astronaut #Pilot #CEO #businessman #boss… https://t.co/rksHQmeZsb
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @Jeff2Serenity @TrampolinRocket @John_Gardi @TheLurioReport @SpaceX Heck, even Andy Pazstor is more objective wrt S… https://t.co/OfyB4XE6Bp
# Sentiment(polarity=0.25, subjectivity=0.3)
#
# Elon Musk: Tesla, SpaceX, and the Quest for a Fantastic Future https://t.co/oxKsaz5eRa
# Sentiment(polarity=0.2, subjectivity=0.5125)
#
# RT @digikey: After a month long stay at the #space station, Dragon capsule returns to Earth via @DigitalTrends https://t.co/wlPg8tF7gv http…
# Sentiment(polarity=-0.05, subjectivity=0.4)
#
# Commercial Crew Test Launches by SpaceX, Boeing Will Begin This Year
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @Jeff2Serenity @TrampolinRocket @TheLurioReport @SpaceX Yeah, I know. I DID read it (know thine enemy). 😎
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @webdevMason: Gwynne Shotwell is a personal hero. She’s President &amp; COO at SpaceX.
#
# “SpaceX has a female president?”
#
# Yeah, it does. If…
# Sentiment(polarity=0.0, subjectivity=0.23333333333333334)
#
# RT @ClickHole: Space Flight Setback: SpaceX Has Lost A Falcon 9 Rocket After It Landed In A Mean Old Neighbor’s Backyard https://t.co/Gs1Gg…
# Sentiment(polarity=-0.10625, subjectivity=0.44375)
#
# RT @SpeakToMeInDots: This is how much they tell us it costs to send things (ie: gorilla suit, guitars, flutes, stuffed toys, etc) to the im…
# Sentiment(polarity=0.2, subjectivity=0.2)
#
# RT @ClickHole: Space Flight Setback: SpaceX Has Lost A Falcon 9 Rocket After It Landed In A Mean Old Neighbor’s Backyard https://t.co/Gs1Gg…
# Sentiment(polarity=-0.10625, subjectivity=0.44375)
#
# SpaceXu2019s Falcon Heavy rocket sets up at Cape Canaveral ahead of launch  SpaceX won’t hit its 2017 target for a… https://t.co/lABPgmFa8n
# Sentiment(polarity=-0.2, subjectivity=0.5)
#
# SpaceX to fire up Falcon Heavy's 27 engines this week https://t.co/VgmBv3Xd7c via @CNET
# Sentiment(polarity=-0.2, subjectivity=0.5)
#
# RT @ClickHole: Space Flight Setback: SpaceX Has Lost A Falcon 9 Rocket After It Landed In A Mean Old Neighbor’s Backyard https://t.co/Gs1Gg…
# Sentiment(polarity=-0.10625, subjectivity=0.44375)
#
# @elonmusk Hi Elon! Our local students would LOVE a trip to SpaceX! Your media relations team told us you do not do… https://t.co/SbZ0sYlVbo
# Sentiment(polarity=0.3125, subjectivity=0.3)
#
# NASA Safety Watchdogs Raise Concerns About SpaceX, Boeing Spacecraft https://t.co/NahF5nGskE
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @SatSpy: A #satellite that might have been called #Zuma, may or may not have been launched and lost on a #SpaceX #Falcon9 mission. We ca…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @ClickHole: Space Flight Setback: SpaceX Has Lost A Falcon 9 Rocket After It Landed In A Mean Old Neighbor’s Backyard https://t.co/Gs1Gg…
# Sentiment(polarity=-0.10625, subjectivity=0.44375)
#
# https://t.co/LpZbUHgSMS
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @jeff_foust: Statement from SpaceX’s Gwynne Shotwell this morning that Falcon 9 “did everything correctly” on the Zuma launch; claims to…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @wavetossed: #QAnon Here is an interesting 8239 https://t.co/VHYYU9wEpv
# Not Spacex Falcon9 Vandenberg, or is it about to be? Future Mars…
# Sentiment(polarity=0.25, subjectivity=0.3125)
#
# RT @webdevMason: Gwynne Shotwell is a personal hero. She’s President &amp; COO at SpaceX.
#
# “SpaceX has a female president?”
#
# Yeah, it does. If…
# Sentiment(polarity=0.0, subjectivity=0.23333333333333334)
#
# @TrampolinRocket @John_Gardi @TheLurioReport @SpaceX Look at where he works and where they get funding.  No surpris… https://t.co/Eyw0DxDaC5
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# #QAnon Here is an interesting 8239 https://t.co/VHYYU9wEpv
# Not Spacex Falcon9 Vandenberg, or is it about to be? Future Mars shot?
# Sentiment(polarity=0.25, subjectivity=0.3125)
#
# RT @iamkarenmunoz: Awww
# @elonmusk #elonmusk @SpaceX https://t.co/r14O4kHa92
# Sentiment(polarity=0.4, subjectivity=0.9)
#
# @322997am1 @SpaceX @NASA Definitely due to the heat of reentry. The Dragon is doing about 17,000mph in orbit, and m… https://t.co/7DYDyvu1Hx
# Sentiment(polarity=-0.125, subjectivity=0.375)
#
# RT @ClickHole: Space Flight Setback: SpaceX Has Lost A Falcon 9 Rocket After It Landed In A Mean Old Neighbor’s Backyard https://t.co/Gs1Gg…
# Sentiment(polarity=-0.10625, subjectivity=0.44375)
#
# I added a video to a @YouTube playlist https://t.co/a8LFFKbxXs Unsuccessful launch of SpaceX? UFO? massive light in LOS ANGELES sky
# Sentiment(polarity=0.2, subjectivity=0.85)
#
# How reusable rockets are paving the way for the next phase of space exploration https://t.co/iYk1iVLCBl
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# Safety Panel Raises Concerns about #SpaceX Falcon 9 Pressure Vessel for Commercial Crew Missions #NASA  https://t.co/NxS27BTIL7
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @ClickHole: Space Flight Setback: SpaceX Has Lost A Falcon 9 Rocket After It Landed In A Mean Old Neighbor’s Backyard https://t.co/Gs1Gg…
# Sentiment(polarity=-0.10625, subjectivity=0.44375)
#
# RT @NewScienceWrld: #SpaceX Will Test the Engines of the World's Most Powerful Rocket Today https://t.co/nVcFMPg8Di https://t.co/DpLcq19XGF
# Sentiment(polarity=0.4, subjectivity=0.75)
#
# SpaceX Will Test the Engines of the World’s Most Powerful Rocket on Tuesday - https://t.co/GnLoFawFZ3 via https://t.co/TSSwAq9Tz4
# Sentiment(polarity=0.4, subjectivity=0.75)
#
# Boeing, SpaceX have razor-thin margins to fly crew missions in 2018
# Sentiment(polarity=0.8, subjectivity=0.9)
#
# The squad pulling up at @SpaceX let’s gooo https://t.co/JdYEdV1Iz9
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @ElonMuskNewsOrg: "We have essentially no patents in SpaceX… if we published patents… the Chinese would just use them as a recipe book."…
# Sentiment(polarity=0.0, subjectivity=0.15)
#
# #Франция Европа и Конгсберг обойдут SpaceX https://t.co/1oZKyoU2ZY
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @Space__Newz: #SpaceX to fire up Falcon Heavy's 27 engines this week https://t.co/reNfGB06Q1
# Sentiment(polarity=-0.2, subjectivity=0.5)
#
# Doubts About SpaceX Reliability Persist As Astronaut Missions Approach https://t.co/pIsLv5ow2v https://t.co/B2AEJtthTo
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @webdevMason: Gwynne Shotwell is a personal hero. She’s President &amp; COO at SpaceX.
#
# “SpaceX has a female president?”
#
# Yeah, it does. If…
# Sentiment(polarity=0.0, subjectivity=0.23333333333333334)
#
# RT @ClickHole: Space Flight Setback: SpaceX Has Lost A Falcon 9 Rocket After It Landed In A Mean Old Neighbor’s Backyard https://t.co/Gs1Gg…
# Sentiment(polarity=-0.10625, subjectivity=0.44375)
#
# RT @CNET: SpaceX's Falcon Heavy, the biggest rocket in the world, could make its first launch as early as Tuesday https://t.co/kiGRIBc9Ql h…
# Sentiment(polarity=0.049999999999999996, subjectivity=0.37777777777777777)
#
# RT @TheEvent2014: SpaceX Denies Any Oversights in Classified Satellite Launch https://t.co/HB7pkllh1n
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @InsideKSC: SLIP: The @SpaceX Falcon Heavy static test fire has again moved to the right. Now NET Tuesday afternoon from @NASAKennedy La…
# Sentiment(polarity=0.1464285714285714, subjectivity=0.4839285714285714)
#
# @ElonMuskNewsOrg May fortune favor SpaceX
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @LarsFavNumIs27 @RayKurz @Snowden @JulianAssange @WLTaskForce #physics #Astronomy #ai #AI #ArtificialIntelligence… https://t.co/vBKTMg4NTb
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# SpaceX to fire up Falcon Heavy's 27 engines this week     – CNET https://t.co/ZNDi6bMsbl
# Sentiment(polarity=-0.2, subjectivity=0.5)
#
# #vid • @YouTube 《 https://t.co/rvkKSVvzdD 》 SpaceX's Zuma Situation is getting Weirder! : #HyperLink… https://t.co/WpJGBnMqY6
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# Мне понравилось видео "SpaceX CRS-13 NASA TV Landing Footage" (https://t.co/nMRI2LEYmC) на @YouTube.
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @ClickHole: Space Flight Setback: SpaceX Has Lost A Falcon 9 Rocket After It Landed In A Mean Old Neighbor’s Backyard https://t.co/Gs1Gg…
# Sentiment(polarity=-0.10625, subjectivity=0.44375)
#
# It's like non-copyright-infringement mini SpaceX.
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
import pandas as pd
data = pd.read_csv('spacex.csv', sep=',')
print (data)
data.dropna()
data.dropna().to_csv('SpX_tweet.csv')
# Out:
#                                                  TWEET  POLARITY  SUBJECTIVITY
# 0    @AmazingSpace2 @NASA @SpaceX Totally know you ...  0.121875      0.534375
# 1    RT @ClickHole: Space Flight Setback: SpaceX Ha... -0.106250      0.443750
# 2    RT @christianbok: Marie Claire takes an intere...  0.000000      0.000000
# 3         @SpaceX_x @BrianNoahYT Jaman 😂 kapppppppaaaa  0.000000      0.000000
# 4    RT @ClickHole: Space Flight Setback: SpaceX Ha... -0.106250      0.443750
# 5    RT @manuginobili: Very exciting visit to @Spac...  0.328750      0.525000
# 6    RT @ClickHole: Space Flight Setback: SpaceX Ha... -0.106250      0.443750
# 7    RT @webdevMason: Gwynne Shotwell is a personal...       NaN           NaN
# 8                     “SpaceX has a female president?”       NaN           NaN
# 9                                   Yeah  it does. If…  0.000000      0.233333
# 10   @AstronautAbby Abby!  You don't need a *Rocket...  0.000000      0.000000
# 11   SpaceX Denies Any Oversights in Classified Sat...  0.000000      0.000000
# 12   RT @SpaceX: Dragon is headed to port with ~4 1...  0.000000      0.000000
# 13   #vid • @YouTube 《 https://t.co/VPCDLQx97k 》 Sp...  0.000000      1.000000
# 14   RT @NorwichAS: SpaceX realign Falcon Heavy Sta...  0.166667      0.566667
# 15   @AJ_FI @pbdes Recovered fairing - quicker than...  0.000000      0.000000
# 16   RT @ElonMuskNewsOrg: "We have essentially no p...  0.000000      0.150000
# 17   #SpaceX The Space Review: The mystery of #Zuma...  0.000000      0.000000
# 18   RT @ClickHole: Space Flight Setback: SpaceX Ha... -0.106250      0.443750
# 19   @AriParranda @clarin @todonoticias Yo te recom...  0.000000      0.000000
# 20   RT @FortuneMagazine: SpaceX will test the engi...  0.400000      0.750000
# 21   Station cargo ship brings science down to Eart... -0.155556      0.288889
# 22   RT @ElonMuskNewsOrg: "We have essentially no p...  0.000000      0.150000
# 23                           @NASA @isro @JAXA_en @esa       NaN           NaN
# 24                                            @csa_asc       NaN           NaN
# 25                      @SpaceX @spacegovuk @roscosmos       NaN           NaN
# 26                                          @neiltyson       NaN           NaN
# 27                              @BillNye @TheRealBuzz        NaN           NaN
# 28             This is a craz… https://t.co/5cFZwg6rvU  0.000000      0.000000
# 29   RT @TIME: SpaceX is about to test the world's ...  0.400000      0.750000
# ..                                                 ...       ...           ...
# 94                            RT @iamkarenmunoz: Awww        NaN           NaN
# 95   @elonmusk #elonmusk @SpaceX https://t.co/r14O4...  0.400000      0.900000
# 96   @322997am1 @SpaceX @NASA Definitely due to the... -0.125000      0.375000
# 97   RT @ClickHole: Space Flight Setback: SpaceX Ha... -0.106250      0.443750
# 98   I added a video to a @YouTube playlist https:/...  0.200000      0.850000
# 99   How reusable rockets are paving the way for th...  0.000000      0.000000
# 100  Safety Panel Raises Concerns about #SpaceX Fal...  0.000000      0.000000
# 101  RT @ClickHole: Space Flight Setback: SpaceX Ha... -0.106250      0.443750
# 102  RT @NewScienceWrld: #SpaceX Will Test the Engi...  0.400000      0.750000
# 103  SpaceX Will Test the Engines of the World’s Mo...  0.400000      0.750000
# 104  Boeing  SpaceX have razor-thin margins to fly ...  0.800000      0.900000
# 105  The squad pulling up at @SpaceX let’s gooo htt...  0.000000      0.000000
# 106  RT @ElonMuskNewsOrg: "We have essentially no p...  0.000000      0.150000
# 107  #Франция Европа и Конгсберг обойдут SpaceX htt...  0.000000      0.000000
# 108  RT @Space__Newz: #SpaceX to fire up Falcon Hea... -0.200000      0.500000
# 109  Doubts About SpaceX Reliability Persist As Ast...  0.000000      0.000000
# 110  RT @webdevMason: Gwynne Shotwell is a personal...       NaN           NaN
# 111                   “SpaceX has a female president?”       NaN           NaN
# 112                                 Yeah  it does. If…  0.000000      0.233333
# 113  RT @ClickHole: Space Flight Setback: SpaceX Ha... -0.106250      0.443750
# 114  RT @CNET: SpaceX's Falcon Heavy  the biggest r...  0.050000      0.377778
# 115  RT @TheEvent2014: SpaceX Denies Any Oversights...  0.000000      0.000000
# 116  RT @InsideKSC: SLIP: The @SpaceX Falcon Heavy ...  0.146429      0.483929
# 117          @ElonMuskNewsOrg May fortune favor SpaceX  0.000000      0.000000
# 118  @LarsFavNumIs27 @RayKurz @Snowden @JulianAssan...  0.000000      0.000000
# 119  SpaceX to fire up Falcon Heavy's 27 engines th... -0.200000      0.500000
# 120  #vid • @YouTube 《 https://t.co/rvkKSVvzdD 》 Sp...  0.000000      0.000000
# 121  Мне понравилось видео "SpaceX CRS-13 NASA TV L...  0.000000      0.000000
# 122  RT @ClickHole: Space Flight Setback: SpaceX Ha... -0.106250      0.443750
# 123  It's like non-copyright-infringement mini SpaceX.  0.000000      0.000000
#
# [124 rows x 3 columns]
